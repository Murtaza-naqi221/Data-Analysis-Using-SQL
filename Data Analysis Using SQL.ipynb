# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import sqlite3
import matplotlib.pyplot as plt

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

##path = "D:\Data analysis using sql"  #Insert path here
database = 'database.sqlite'

# %%
try:
    conn = sqlite3.connect(database)
    cur = conn.cursor()
    print("Opened successfully")
except Exception as e:
    print("error", str(e))
# Out:
# Opened successfully

# %%
tables = pd.read_sql("""SELECT *
                        FROM sqlite_master
                        WHERE type='table';""", conn)
tables
# Out:
#     type               name           tbl_name  rootpage  \
# 0  table    sqlite_sequence    sqlite_sequence         4
# 1  table  Player_Attributes  Player_Attributes        11
# 2  table             Player             Player        14
# 3  table              Match              Match        18
# 4  table             League             League        24
# 5  table            Country            Country        26
# 6  table               Team               Team        29
# 7  table    Team_Attributes    Team_Attributes         2
#
#                                                  sql
# 0             CREATE TABLE sqlite_sequence(name,seq)
# 1  CREATE TABLE "Player_Attributes" (\n\t`id`\tIN...
# 2  CREATE TABLE `Player` (\n\t`id`\tINTEGER PRIMA...
# 3  CREATE TABLE `Match` (\n\t`id`\tINTEGER PRIMAR...
# 4  CREATE TABLE `League` (\n\t`id`\tINTEGER PRIMA...
# 5  CREATE TABLE `Country` (\n\t`id`\tINTEGER PRIM...
# 6  CREATE TABLE "Team" (\n\t`id`\tINTEGER PRIMARY...
# ...

# %%
pd.read_sql?

# %%
countries = pd.read_sql("""SELECT *
                        FROM country""", conn)
countries
# Out:
#        id         name
# 0       1      Belgium
# 1    1729      England
# 2    4769       France
# 3    7809      Germany
# 4   10257        Italy
# 5   13274  Netherlands
# 6   15722       Poland
# 7   17642     Portugal
# 8   19694     Scotland
# 9   21518        Spain
# 10  24558  Switzerland

# %%
leagues = pd.read_sql("""SELECT *
                        FROM league""", conn)

leagues
# Out:
#        id  country_id                      name
# 0       1           1    Belgium Jupiler League
# 1    1729        1729    England Premier League
# 2    4769        4769            France Ligue 1
# 3    7809        7809     Germany 1. Bundesliga
# 4   10257       10257             Italy Serie A
# 5   13274       13274    Netherlands Eredivisie
# 6   15722       15722        Poland Ekstraklasa
# 7   17642       17642  Portugal Liga ZON Sagres
# 8   19694       19694   Scotland Premier League
# 9   21518       21518           Spain LIGA BBVA
# 10  24558       24558  Switzerland Super League

# %%
pd.read_sql("""SELECT * 
            FROM country
            JOIN league
            ON country.id = league.id""", conn)
# Out:
#        id         name     id  country_id                      name
# 0       1      Belgium      1           1    Belgium Jupiler League
# 1    1729      England   1729        1729    England Premier League
# 2    4769       France   4769        4769            France Ligue 1
# 3    7809      Germany   7809        7809     Germany 1. Bundesliga
# 4   10257        Italy  10257       10257             Italy Serie A
# 5   13274  Netherlands  13274       13274    Netherlands Eredivisie
# 6   15722       Poland  15722       15722        Poland Ekstraklasa
# 7   17642     Portugal  17642       17642  Portugal Liga ZON Sagres
# 8   19694     Scotland  19694       19694   Scotland Premier League
# 9   21518        Spain  21518       21518           Spain LIGA BBVA
# 10  24558  Switzerland  24558       24558  Switzerland Super League

# %%
team = pd.read_sql("""SELECT *
                    FROM team
                    ORDER BY team_long_name
                    LIMIT 10""", conn)
team
# Out:
#       id  team_api_id  team_fifa_api_id        team_long_name team_short_name
# 0  16848         8350                29  1. FC Kaiserslautern             KAI
# 1  15624         8722                31            1. FC Köln             FCK
# 2  16239         8165               171        1. FC Nürnberg             NUR
# 3  16243         9905               169       1. FSV Mainz 05             MAI
# 4  11817         8576               614            AC Ajaccio             AJA
# 5  11074       108893            111989      AC Arles-Avignon             ARL
# 6  49116         6493              1714         AC Bellinzona             BEL
# 7  26560        10217               650          ADO Den Haag             HAA
# 8   9537         8583                57            AJ Auxerre             AUX
# 9   9547         9829                69             AS Monaco             MON

# %%
pd.read_sql("""SELECT *
                    FROM match
                    LIMIT 10""", conn)
# Out:
#    id  country_id  league_id     season  stage                 date  \
# 0   1           1          1  2008/2009      1  2008-08-17 00:00:00
# 1   2           1          1  2008/2009      1  2008-08-16 00:00:00
# 2   3           1          1  2008/2009      1  2008-08-16 00:00:00
# 3   4           1          1  2008/2009      1  2008-08-17 00:00:00
# 4   5           1          1  2008/2009      1  2008-08-16 00:00:00
# 5   6           1          1  2008/2009      1  2008-09-24 00:00:00
# 6   7           1          1  2008/2009      1  2008-08-16 00:00:00
# 7   8           1          1  2008/2009      1  2008-08-16 00:00:00
# 8   9           1          1  2008/2009      1  2008-08-16 00:00:00
# 9  10           1          1  2008/2009     10  2008-11-01 00:00:00
#
#    match_api_id  home_team_api_id  away_team_api_id  home_team_goal  ...  \
# 0        492473              9987              9993               1  ...
# ...

# %%
detailed_matches = pd.read_sql("""SELECT Match.id, 
                                        Country.name AS country_name, 
                                        League.name AS league_name, 
                                        season, 
                                        stage, 
                                        date,
                                        HT.team_long_name AS  home_team,
                                        AT.team_long_name AS away_team,
                                        home_team_goal, 
                                        away_team_goal                                        
                                FROM Match
                                JOIN Country on Country.id = Match.country_id
                                JOIN League on League.id = Match.league_id
                                JOIN Team AS HT on HT.team_api_id = Match.home_team_api_id
                                JOIN Team AS AT on AT.team_api_id = Match.away_team_api_id
                                WHERE country_name = 'Spain'
                                ORDER by date
                                LIMIT 10;""", conn)
detailed_matches
# Out:
#       id country_name      league_name     season  stage                 date  \
# 0  21518        Spain  Spain LIGA BBVA  2008/2009      1  2008-08-30 00:00:00
# 1  21525        Spain  Spain LIGA BBVA  2008/2009      1  2008-08-30 00:00:00
# 2  21519        Spain  Spain LIGA BBVA  2008/2009      1  2008-08-31 00:00:00
# 3  21520        Spain  Spain LIGA BBVA  2008/2009      1  2008-08-31 00:00:00
# 4  21521        Spain  Spain LIGA BBVA  2008/2009      1  2008-08-31 00:00:00
# 5  21522        Spain  Spain LIGA BBVA  2008/2009      1  2008-08-31 00:00:00
# 6  21523        Spain  Spain LIGA BBVA  2008/2009      1  2008-08-31 00:00:00
# 7  21524        Spain  Spain LIGA BBVA  2008/2009      1  2008-08-31 00:00:00
# 8  21526        Spain  Spain LIGA BBVA  2008/2009      1  2008-08-31 00:00:00
# 9  21527        Spain  Spain LIGA BBVA  2008/2009      1  2008-08-31 00:00:00
#
#                    home_team        away_team  home_team_goal  away_team_goal
# ...

# %%
number_OF_goals = pd.read_sql("""SELECT Country.name AS country_name,
                                League.name AS league_name,
                                season,
                                avg(home_team_goal),
                                avg(away_team_goal)
                                FROM Match
                                JOIN Country on Country.id = Match.country_id
                                JOIN League on League.id = Match.league_id
                                JOIN Team AS HT on HT.team_api_id = Match.home_team_api_id
                                JOIN Team AS AT on AT.team_api_id = Match.away_team_api_id
                                WHERE country_name in ('Spain','England')
                                GROUP BY country_name, league_name, season
                                ORDER BY country_name, season DESC""", conn)
number_OF_goals
# Out:
#    country_name             league_name     season  avg(home_team_goal)  \
# 0       England  England Premier League  2015/2016             1.492105
# 1       England  England Premier League  2014/2015             1.473684
# 2       England  England Premier League  2013/2014             1.573684
# 3       England  England Premier League  2012/2013             1.557895
# 4       England  England Premier League  2011/2012             1.589474
# 5       England  England Premier League  2010/2011             1.623684
# 6       England  England Premier League  2009/2010             1.697368
# 7       England  England Premier League  2008/2009             1.400000
# 8         Spain         Spain LIGA BBVA  2015/2016             1.618421
# 9         Spain         Spain LIGA BBVA  2014/2015             1.536842
# 10        Spain         Spain LIGA BBVA  2013/2014             1.631579
# 11        Spain         Spain LIGA BBVA  2012/2013             1.686842
# ...

# %%
leages_by_season = pd.read_sql("""SELECT Country.name AS country_name, 
                                        League.name AS league_name, 
                                        season,
                                        avg(home_team_goal) AS avg_home_team_scors, 
                                        avg(away_team_goal) AS avg_away_team_goals                                   
                                FROM Match
                                JOIN Country on Country.id = Match.country_id
                                JOIN League on League.id = Match.league_id
                                LEFT JOIN Team AS HT on HT.team_api_id = Match.home_team_api_id
                                LEFT JOIN Team AS AT on AT.team_api_id = Match.away_team_api_id
                                WHERE country_name in ('Spain', 'Germany', 'France', 'Italy', 'England')
                                GROUP BY Country.name, League.name, season
                                ORDER BY Country.name, League.name, season DESC
                                ;""", conn)
leages_by_season
# Out:
#    country_name             league_name     season  avg_home_team_scors  \
# 0       England  England Premier League  2015/2016             1.492105
# 1       England  England Premier League  2014/2015             1.473684
# 2       England  England Premier League  2013/2014             1.573684
# 3       England  England Premier League  2012/2013             1.557895
# 4       England  England Premier League  2011/2012             1.589474
# 5       England  England Premier League  2010/2011             1.623684
# 6       England  England Premier League  2009/2010             1.697368
# 7       England  England Premier League  2008/2009             1.400000
# 8        France          France Ligue 1  2015/2016             1.436842
# 9        France          France Ligue 1  2014/2015             1.410526
# 10       France          France Ligue 1  2013/2014             1.415789
# 11       France          France Ligue 1  2012/2013             1.468421
# ...

# %%
case_wala = pd.read_sql("""SELECT name,
                        CASE 
                            WHEN name like '%LIGA%' THEN 'spanish league'
                            ELSE 'NON SPANISH'
                            END AS SPAIN_NAME
                        FROM league;""", conn)
case_wala
# Out:
#                         name      SPAIN_NAME
# 0     Belgium Jupiler League     NON SPANISH
# 1     England Premier League     NON SPANISH
# 2             France Ligue 1     NON SPANISH
# 3      Germany 1. Bundesliga  spanish league
# 4              Italy Serie A     NON SPANISH
# 5     Netherlands Eredivisie     NON SPANISH
# 6         Poland Ekstraklasa     NON SPANISH
# 7   Portugal Liga ZON Sagres  spanish league
# 8    Scotland Premier League     NON SPANISH
# 9            Spain LIGA BBVA  spanish league
# 10  Switzerland Super League     NON SPANISH

# %%
countries = pd.read_sql("""SELECT name,
                        CASE 
                            WHEN id = 1 THEN 'ID IS VALID'
                            ELSE 'NON VALID'
                            END AS id_valid
                        FROM country""", conn)
countries
# Out:
#            name     id_valid
# 0       Belgium  ID IS VALID
# 1       England    NON VALID
# 2        France    NON VALID
# 3       Germany    NON VALID
# 4         Italy    NON VALID
# 5   Netherlands    NON VALID
# 6        Poland    NON VALID
# 7      Portugal    NON VALID
# 8      Scotland    NON VALID
# 9         Spain    NON VALID
# 10  Switzerland    NON VALID
